# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
#1st of all seeing with train test split
from sklearn.model_selection import train_test_split

# %%
X = df.drop('species',axis=1)
y = df['species']

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors=10)

# %%
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
model_knn.score(X_test,y_test)
# Out:
# 0.98

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(gamma='auto')

# %%
model_svm.fit(X_train,y_train)
# Out:
# SVC(gamma='auto')

# %%
model_svm.score(X_test,y_test)
# Out:
# 1.0

# %%
#Now using grid search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier = GridSearchCV((model_svm),{
  'C':[1,10,20,30],
  'kernel':['rbf','linear'],
},cv= 5,return_train_score=False)

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.01042943, 0.00213132, 0.00230446, 0.00254817, 0.00197182,
#         0.00255618, 0.00317721, 0.00202246]),
#  'std_fit_time': array([0.01624673, 0.00070375, 0.00091045, 0.00121049, 0.00064906,
#         0.00050837, 0.00094192, 0.00062242]),
#  'mean_score_time': array([0.00246038, 0.00156894, 0.0016305 , 0.00138702, 0.00162964,
#         0.00163336, 0.00229931, 0.00164318]),
#  'std_score_time': array([0.00140427, 0.00050416, 0.00054824, 0.00034021, 0.00060967,
#         0.00012854, 0.00053798, 0.00050555]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 30, 'kernel': 'rbf'},
#   {'C': 30, 'kernel': 'linear'}],
#  'split0_test_score': array([0.96666667, 0.96666667, 0.96666667, 1.        , 0.96666667,
#         1.        , 0.96666667, 1.        ]),
#  'split1_test_score': array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  'split2_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.9       , 0.9       ,
#         0.9       , 0.9       , 0.9       ]),
#  'split3_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.96666667, 0.96666667,
#         0.93333333, 0.93333333, 0.9       ]),
#  'split4_test_score': array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  'mean_test_score': array([0.98      , 0.98      , 0.98      , 0.97333333, 0.96666667,
#         0.96666667, 0.96      , 0.96      ]),
#  'std_test_score': array([0.01632993, 0.01632993, 0.01632993, 0.03887301, 0.03651484,
#         0.0421637 , 0.03887301, 0.04898979]),
#  'rank_test_score': array([1, 1, 1, 4, 5, 6, 7, 7], dtype=int32)}

# %%
results = pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.010429      0.016247         0.002460        0.001404        1
# 1       0.002131      0.000704         0.001569        0.000504        1
# 2       0.002304      0.000910         0.001630        0.000548       10
# 3       0.002548      0.001210         0.001387        0.000340       10
# 4       0.001972      0.000649         0.001630        0.000610       20
# 5       0.002556      0.000508         0.001633        0.000129       20
# 6       0.003177      0.000942         0.002299        0.000538       30
# 7       0.002022      0.000622         0.001643        0.000506       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# 5       linear  {'C': 20, 'kernel': 'linear'}           1.000000
# 6          rbf     {'C': 30, 'kernel': 'rbf'}           0.966667
# 7       linear  {'C': 30, 'kernel': 'linear'}           1.000000
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
# 2                1.0           0.966667           0.966667                1.0
# 3                1.0           0.900000           0.966667                1.0
# 4                1.0           0.900000           0.966667                1.0
# 5                1.0           0.900000           0.933333                1.0
# 6                1.0           0.900000           0.933333                1.0
# 7                1.0           0.900000           0.900000                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.980000        0.016330                1
# 1         0.980000        0.016330                1
# 2         0.980000        0.016330                1
# 3         0.973333        0.038873                4
# 4         0.966667        0.036515                5
# 5         0.966667        0.042164                6
# 6         0.960000        0.038873                7
# 7         0.960000        0.048990                7

# %%
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %%
#After using grid search cv the model score
model_svm.score(X,y)
# Out:
# 0.9866666666666667

# %%
classifier1 = GridSearchCV((model_knn),{
  'n_neighbors':[3,5,7,9,11],
  'weights':['uniform','distance'],
  'metric':['euclidean','manhattan','minkowski'],
  'p':[1,2]
},cv= 5,return_train_score=False)

# %%
classifier1.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=10),
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9, 11], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']})

# %%
classifier1.cv_results_

# %%
results1 = pd.DataFrame(classifier1.cv_results_)

# %%
results1
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.017162      0.026893         0.011259        0.013062    euclidean
# 1        0.002168      0.000643         0.003231        0.001146    euclidean
# 2        0.002489      0.001203         0.002729        0.000377    euclidean
# 3        0.003423      0.001601         0.002654        0.001132    euclidean
# 4        0.002368      0.001140         0.002989        0.000777    euclidean
# 5        0.002277      0.000532         0.003139        0.000884    euclidean
# 6        0.003271      0.001054         0.003819        0.000509    euclidean
# 7        0.004626      0.003738         0.003967        0.002321    euclidean
# 8        0.002044      0.000325         0.004175        0.001612    euclidean
# 9        0.003091      0.001220         0.003426        0.001093    euclidean
# 10       0.002103      0.000712         0.003671        0.001160    euclidean
# 11       0.002095      0.000465         0.002459        0.000534    euclidean
# 12       0.001887      0.000722         0.002829        0.000337    euclidean
# 13       0.001801      0.000537         0.002474        0.000805    euclidean
# 14       0.002262      0.000761         0.002443        0.000336    euclidean
# 15       0.001809      0.000347         0.002211        0.000506    euclidean
# 16       0.003392      0.000727         0.004803        0.001768    euclidean
# 17       0.001838      0.000310         0.002597        0.000699    euclidean
# 18       0.001866      0.000669         0.002920        0.000807    euclidean
# 19       0.001432      0.000099         0.001963        0.000643    euclidean
# 20       0.002146      0.000682         0.003487        0.001049    manhattan
# 21       0.001736      0.000408         0.001983        0.000527    manhattan
# 22       0.001570      0.000237         0.002730        0.000772    manhattan
# 23       0.001752      0.000709         0.001987        0.000623    manhattan
# 24       0.001482      0.000171         0.002459        0.000666    manhattan
# 25       0.001680      0.000351         0.001677        0.000113    manhattan
# 26       0.001579      0.000431         0.002419        0.000847    manhattan
# 27       0.001635      0.000447         0.001727        0.000304    manhattan
# 28       0.001444      0.000133         0.002756        0.000950    manhattan
# 29       0.001514      0.000305         0.001681        0.000149    manhattan
# 30       0.001539      0.000313         0.002633        0.000859    manhattan
# 31       0.002044      0.000897         0.001942        0.000513    manhattan
# 32       0.001565      0.000233         0.002535        0.000497    manhattan
# 33       0.001483      0.000289         0.001735        0.000202    manhattan
# 34       0.001718      0.000565         0.002127        0.000122    manhattan
# 35       0.001671      0.000321         0.001804        0.000400    manhattan
# 36       0.001363      0.000048         0.002409        0.000725    manhattan
# 37       0.001841      0.000953         0.002240        0.000478    manhattan
# 38       0.001464      0.000211         0.002343        0.000577    manhattan
# 39       0.001650      0.000589         0.001621        0.000138    manhattan
# 40       0.001377      0.000061         0.003173        0.002270    minkowski
# 41       0.001330      0.000041         0.001877        0.000747    minkowski
# 42       0.001739      0.000484         0.002665        0.000875    minkowski
# 43       0.001504      0.000287         0.001769        0.000355    minkowski
# 44       0.001533      0.000165         0.002916        0.001308    minkowski
# 45       0.001495      0.000296         0.001790        0.000263    minkowski
# 46       0.001645      0.000427         0.002628        0.000571    minkowski
# 47       0.001757      0.000654         0.001835        0.000324    minkowski
# 48       0.001398      0.000063         0.002367        0.000504    minkowski
# 49       0.001631      0.000355         0.002044        0.000551    minkowski
# 50       0.001729      0.000338         0.002877        0.000880    minkowski
# 51       0.001397      0.000076         0.001917        0.000699    minkowski
# 52       0.001534      0.000401         0.002420        0.000650    minkowski
# 53       0.001366      0.000058         0.002069        0.000620    minkowski
# 54       0.001510      0.000350         0.002143        0.000170    minkowski
# 55       0.001695      0.000734         0.002022        0.000563    minkowski
# 56       0.001483      0.000172         0.002416        0.000525    minkowski
# 57       0.001702      0.000477         0.001959        0.000487    minkowski
# 58       0.001443      0.000132         0.002294        0.000310    minkowski
# 59       0.001661      0.000403         0.001654        0.000111    minkowski
#
#     param_n_neighbors  param_p param_weights  \
# 0                   3        1       uniform
# 1                   3        1      distance
# 2                   3        2       uniform
# 3                   3        2      distance
# 4                   5        1       uniform
# 5                   5        1      distance
# 6                   5        2       uniform
# 7                   5        2      distance
# 8                   7        1       uniform
# 9                   7        1      distance
# 10                  7        2       uniform
# 11                  7        2      distance
# 12                  9        1       uniform
# 13                  9        1      distance
# 14                  9        2       uniform
# 15                  9        2      distance
# 16                 11        1       uniform
# 17                 11        1      distance
# 18                 11        2       uniform
# 19                 11        2      distance
# 20                  3        1       uniform
# 21                  3        1      distance
# 22                  3        2       uniform
# 23                  3        2      distance
# 24                  5        1       uniform
# 25                  5        1      distance
# 26                  5        2       uniform
# 27                  5        2      distance
# 28                  7        1       uniform
# 29                  7        1      distance
# 30                  7        2       uniform
# 31                  7        2      distance
# 32                  9        1       uniform
# 33                  9        1      distance
# 34                  9        2       uniform
# 35                  9        2      distance
# 36                 11        1       uniform
# 37                 11        1      distance
# 38                 11        2       uniform
# 39                 11        2      distance
# 40                  3        1       uniform
# 41                  3        1      distance
# 42                  3        2       uniform
# 43                  3        2      distance
# 44                  5        1       uniform
# 45                  5        1      distance
# 46                  5        2       uniform
# 47                  5        2      distance
# 48                  7        1       uniform
# 49                  7        1      distance
# 50                  7        2       uniform
# 51                  7        2      distance
# 52                  9        1       uniform
# 53                  9        1      distance
# 54                  9        2       uniform
# 55                  9        2      distance
# 56                 11        1       uniform
# 57                 11        1      distance
# 58                 11        2       uniform
# 59                 11        2      distance
#
#                                                params  split0_test_score  \
# 0   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.966667
# 1   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.966667
# 2   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.966667
# 3   {'metric': 'euclidean', 'n_neighbors': 3, 'p':...           0.966667
# 4   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.966667
# 5   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.966667
# 6   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.966667
# 7   {'metric': 'euclidean', 'n_neighbors': 5, 'p':...           0.966667
# 8   {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.966667
# 9   {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.966667
# 10  {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.966667
# 11  {'metric': 'euclidean', 'n_neighbors': 7, 'p':...           0.966667
# 12  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.966667
# 13  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.966667
# 14  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.966667
# 15  {'metric': 'euclidean', 'n_neighbors': 9, 'p':...           0.966667
# 16  {'metric': 'euclidean', 'n_neighbors': 11, 'p'...           0.933333
# 17  {'metric': 'euclidean', 'n_neighbors': 11, 'p'...           0.966667
# 18  {'metric': 'euclidean', 'n_neighbors': 11, 'p'...           0.933333
# 19  {'metric': 'euclidean', 'n_neighbors': 11, 'p'...           0.966667
# 20  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.966667
# 21  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.966667
# 22  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.966667
# 23  {'metric': 'manhattan', 'n_neighbors': 3, 'p':...           0.966667
# 24  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.966667
# 25  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.966667
# 26  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.966667
# 27  {'metric': 'manhattan', 'n_neighbors': 5, 'p':...           0.966667
# 28  {'metric': 'manhattan', 'n_neighbors': 7, 'p':...           0.966667
# 29  {'metric': 'manhattan', 'n_neighbors': 7, 'p':...           0.966667
# 30  {'metric': 'manhattan', 'n_neighbors': 7, 'p':...           0.966667
# 31  {'metric': 'manhattan', 'n_neighbors': 7, 'p':...           0.966667
# 32  {'metric': 'manhattan', 'n_neighbors': 9, 'p':...           0.966667
# 33  {'metric': 'manhattan', 'n_neighbors': 9, 'p':...           0.966667
# 34  {'metric': 'manhattan', 'n_neighbors': 9, 'p':...           0.966667
# 35  {'metric': 'manhattan', 'n_neighbors': 9, 'p':...           0.966667
# 36  {'metric': 'manhattan', 'n_neighbors': 11, 'p'...           0.966667
# 37  {'metric': 'manhattan', 'n_neighbors': 11, 'p'...           0.966667
# 38  {'metric': 'manhattan', 'n_neighbors': 11, 'p'...           0.966667
# 39  {'metric': 'manhattan', 'n_neighbors': 11, 'p'...           0.966667
# 40  {'metric': 'minkowski', 'n_neighbors': 3, 'p':...           0.966667
# 41  {'metric': 'minkowski', 'n_neighbors': 3, 'p':...           0.966667
# 42  {'metric': 'minkowski', 'n_neighbors': 3, 'p':...           0.966667
# 43  {'metric': 'minkowski', 'n_neighbors': 3, 'p':...           0.966667
# 44  {'metric': 'minkowski', 'n_neighbors': 5, 'p':...           0.966667
# 45  {'metric': 'minkowski', 'n_neighbors': 5, 'p':...           0.966667
# 46  {'metric': 'minkowski', 'n_neighbors': 5, 'p':...           0.966667
# 47  {'metric': 'minkowski', 'n_neighbors': 5, 'p':...           0.966667
# 48  {'metric': 'minkowski', 'n_neighbors': 7, 'p':...           0.966667
# 49  {'metric': 'minkowski', 'n_neighbors': 7, 'p':...           0.966667
# 50  {'metric': 'minkowski', 'n_neighbors': 7, 'p':...           0.966667
# 51  {'metric': 'minkowski', 'n_neighbors': 7, 'p':...           0.966667
# 52  {'metric': 'minkowski', 'n_neighbors': 9, 'p':...           0.966667
# 53  {'metric': 'minkowski', 'n_neighbors': 9, 'p':...           0.966667
# 54  {'metric': 'minkowski', 'n_neighbors': 9, 'p':...           0.966667
# 55  {'metric': 'minkowski', 'n_neighbors': 9, 'p':...           0.966667
# 56  {'metric': 'minkowski', 'n_neighbors': 11, 'p'...           0.966667
# 57  {'metric': 'minkowski', 'n_neighbors': 11, 'p'...           0.966667
# 58  {'metric': 'minkowski', 'n_neighbors': 11, 'p'...           0.933333
# 59  {'metric': 'minkowski', 'n_neighbors': 11, 'p'...           0.966667
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.966667           0.933333           0.966667
# 1            0.966667           0.933333           0.966667
# 2            0.966667           0.933333           0.966667
# 3            0.966667           0.933333           0.966667
# 4            1.000000           0.933333           0.966667
# 5            1.000000           0.900000           0.966667
# 6            1.000000           0.933333           0.966667
# 7            1.000000           0.900000           0.966667
# 8            1.000000           0.966667           0.966667
# 9            1.000000           0.966667           0.966667
# 10           1.000000           0.966667           0.966667
# 11           1.000000           0.966667           0.966667
# 12           1.000000           0.966667           0.933333
# 13           1.000000           0.933333           0.966667
# 14           1.000000           0.966667           0.933333
# 15           1.000000           0.933333           0.966667
# 16           1.000000           1.000000           0.966667
# 17           1.000000           1.000000           0.966667
# 18           1.000000           1.000000           0.966667
# 19           1.000000           1.000000           0.966667
# 20           0.966667           0.933333           0.933333
# 21           0.966667           0.933333           0.933333
# 22           0.966667           0.933333           0.933333
# 23           0.966667           0.933333           0.933333
# 24           0.966667           0.900000           0.966667
# 25           0.966667           0.900000           0.966667
# 26           0.966667           0.900000           0.966667
# 27           0.966667           0.900000           0.966667
# 28           1.000000           0.966667           0.933333
# 29           0.966667           0.900000           0.966667
# 30           1.000000           0.966667           0.933333
# 31           0.966667           0.900000           0.966667
# 32           1.000000           0.933333           0.933333
# 33           0.966667           0.900000           0.966667
# 34           1.000000           0.933333           0.933333
# 35           0.966667           0.900000           0.966667
# 36           1.000000           0.966667           0.966667
# 37           1.000000           0.900000           0.966667
# 38           1.000000           0.966667           0.966667
# 39           1.000000           0.900000           0.966667
# 40           0.966667           0.933333           0.933333
# 41           0.966667           0.933333           0.933333
# 42           0.966667           0.933333           0.966667
# 43           0.966667           0.933333           0.966667
# 44           0.966667           0.900000           0.966667
# 45           0.966667           0.900000           0.966667
# 46           1.000000           0.933333           0.966667
# 47           1.000000           0.900000           0.966667
# 48           1.000000           0.966667           0.933333
# 49           0.966667           0.900000           0.966667
# 50           1.000000           0.966667           0.966667
# 51           1.000000           0.966667           0.966667
# 52           1.000000           0.933333           0.933333
# 53           0.966667           0.900000           0.966667
# 54           1.000000           0.966667           0.933333
# 55           1.000000           0.933333           0.966667
# 56           1.000000           0.966667           0.966667
# 57           1.000000           0.900000           0.966667
# 58           1.000000           1.000000           0.966667
# 59           1.000000           1.000000           0.966667
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 1.0         0.966667        0.021082               28
# 1                 1.0         0.966667        0.021082               28
# 2                 1.0         0.966667        0.021082               28
# 3                 1.0         0.966667        0.021082               28
# 4                 1.0         0.973333        0.024944               16
# 5                 1.0         0.966667        0.036515               28
# 6                 1.0         0.973333        0.024944               16
# 7                 1.0         0.966667        0.036515               28
# 8                 1.0         0.980000        0.016330                4
# 9                 1.0         0.980000        0.016330                4
# 10                1.0         0.980000        0.016330                4
# 11                1.0         0.980000        0.016330                4
# 12                1.0         0.973333        0.024944               16
# 13                1.0         0.973333        0.024944               16
# 14                1.0         0.973333        0.024944               16
# 15                1.0         0.973333        0.024944               16
# 16                1.0         0.980000        0.026667                4
# 17                1.0         0.986667        0.016330                1
# 18                1.0         0.980000        0.026667                4
# 19                1.0         0.986667        0.016330                1
# 20                1.0         0.960000        0.024944               55
# 21                1.0         0.960000        0.024944               55
# 22                1.0         0.960000        0.024944               55
# 23                1.0         0.960000        0.024944               55
# 24                1.0         0.960000        0.032660               43
# 25                1.0         0.960000        0.032660               43
# 26                1.0         0.960000        0.032660               43
# 27                1.0         0.960000        0.032660               43
# 28                1.0         0.973333        0.024944               16
# 29                1.0         0.960000        0.032660               43
# 30                1.0         0.973333        0.024944               16
# 31                1.0         0.960000        0.032660               43
# 32                1.0         0.966667        0.029814               28
# 33                1.0         0.960000        0.032660               43
# 34                1.0         0.966667        0.029814               28
# 35                1.0         0.960000        0.032660               43
# 36                1.0         0.980000        0.016330                4
# 37                1.0         0.966667        0.036515               28
# 38                1.0         0.980000        0.016330                4
# 39                1.0         0.966667        0.036515               28
# 40                1.0         0.960000        0.024944               55
# 41                1.0         0.960000        0.024944               55
# 42                1.0         0.966667        0.021082               28
# 43                1.0         0.966667        0.021082               28
# 44                1.0         0.960000        0.032660               43
# 45                1.0         0.960000        0.032660               43
# 46                1.0         0.973333        0.024944               16
# 47                1.0         0.966667        0.036515               28
# 48                1.0         0.973333        0.024944               16
# 49                1.0         0.960000        0.032660               43
# 50                1.0         0.980000        0.016330                4
# 51                1.0         0.980000        0.016330                4
# 52                1.0         0.966667        0.029814               28
# 53                1.0         0.960000        0.032660               43
# 54                1.0         0.973333        0.024944               16
# 55                1.0         0.973333        0.024944               16
# 56                1.0         0.980000        0.016330                4
# 57                1.0         0.966667        0.036515               28
# 58                1.0         0.980000        0.026667                4
# 59                1.0         0.986667        0.016330                1

# %%
results1[['param_n_neighbors','param_weights','param_metric','param_p','mean_test_score']]
# Out:
#     param_n_neighbors param_weights param_metric  param_p  mean_test_score
# 0                   3       uniform    euclidean        1         0.966667
# 1                   3      distance    euclidean        1         0.966667
# 2                   3       uniform    euclidean        2         0.966667
# 3                   3      distance    euclidean        2         0.966667
# 4                   5       uniform    euclidean        1         0.973333
# 5                   5      distance    euclidean        1         0.966667
# 6                   5       uniform    euclidean        2         0.973333
# 7                   5      distance    euclidean        2         0.966667
# 8                   7       uniform    euclidean        1         0.980000
# 9                   7      distance    euclidean        1         0.980000
# 10                  7       uniform    euclidean        2         0.980000
# 11                  7      distance    euclidean        2         0.980000
# 12                  9       uniform    euclidean        1         0.973333
# 13                  9      distance    euclidean        1         0.973333
# 14                  9       uniform    euclidean        2         0.973333
# 15                  9      distance    euclidean        2         0.973333
# 16                 11       uniform    euclidean        1         0.980000
# 17                 11      distance    euclidean        1         0.986667
# 18                 11       uniform    euclidean        2         0.980000
# 19                 11      distance    euclidean        2         0.986667
# 20                  3       uniform    manhattan        1         0.960000
# 21                  3      distance    manhattan        1         0.960000
# 22                  3       uniform    manhattan        2         0.960000
# 23                  3      distance    manhattan        2         0.960000
# 24                  5       uniform    manhattan        1         0.960000
# 25                  5      distance    manhattan        1         0.960000
# 26                  5       uniform    manhattan        2         0.960000
# 27                  5      distance    manhattan        2         0.960000
# 28                  7       uniform    manhattan        1         0.973333
# 29                  7      distance    manhattan        1         0.960000
# 30                  7       uniform    manhattan        2         0.973333
# 31                  7      distance    manhattan        2         0.960000
# 32                  9       uniform    manhattan        1         0.966667
# 33                  9      distance    manhattan        1         0.960000
# 34                  9       uniform    manhattan        2         0.966667
# 35                  9      distance    manhattan        2         0.960000
# 36                 11       uniform    manhattan        1         0.980000
# 37                 11      distance    manhattan        1         0.966667
# 38                 11       uniform    manhattan        2         0.980000
# 39                 11      distance    manhattan        2         0.966667
# 40                  3       uniform    minkowski        1         0.960000
# 41                  3      distance    minkowski        1         0.960000
# 42                  3       uniform    minkowski        2         0.966667
# 43                  3      distance    minkowski        2         0.966667
# 44                  5       uniform    minkowski        1         0.960000
# 45                  5      distance    minkowski        1         0.960000
# 46                  5       uniform    minkowski        2         0.973333
# 47                  5      distance    minkowski        2         0.966667
# 48                  7       uniform    minkowski        1         0.973333
# 49                  7      distance    minkowski        1         0.960000
# 50                  7       uniform    minkowski        2         0.980000
# 51                  7      distance    minkowski        2         0.980000
# 52                  9       uniform    minkowski        1         0.966667
# 53                  9      distance    minkowski        1         0.960000
# 54                  9       uniform    minkowski        2         0.973333
# 55                  9      distance    minkowski        2         0.973333
# 56                 11       uniform    minkowski        1         0.980000
# 57                 11      distance    minkowski        1         0.966667
# 58                 11       uniform    minkowski        2         0.980000
# 59                 11      distance    minkowski        2         0.986667

# %%
model_knn.score(X,y)
# Out:
# 0.9666666666666667
